# %% [markdown]
# ###  TITANIC
# The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this challenge, we ask you to complete the analysis of what sorts of people were likely to survive. In particular, we ask you to apply the tools of machine learning to predict which passengers survived the tragedy.
#
# Practice Skills
# Binary classification and Python
#
# https://www.kaggle.com/c/titanic

# %% [markdown]
# __Partie 1:__ Description des données
# __Partie 2:__ Completion du dataset (Age, Name, Cabin)
# __partie 3:__ tranformation du dataset pour les algo
# __partie 4:__ Algo
# __partie 5:__ Présentation des résultats

# %% [raw]
# # imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 3300)
pd.set_option('display.max_rows', 100)


from IPython.display import Image
#pd.set_option('display.max_colwidth', 100)
#pd.set_option('display.width', 200)
#pd.set_option('display.max_columns',100)
#pd.set_option('display.max_rows', 40)

# %%
filename = "train.csv"
#path = "/Users/kaiim/Downloads/titanic/"
## path with docker
path = "/home/jovyan/work/"
import_text = pd.read_csv(path+filename)
train = pd.DataFrame(import_text)
copy_train = train

# %% [markdown]
# # 1 - Présentation des données

# %%
train.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S

# %% [markdown]
# ## 1-1 - Descriptions des donées
# >__PassengerId__ : numéro du passager  __(int)__
# __Survived__ : survécu = 1, Non survécu = 0  __(int)__
# __Pclass__ : Catégorie du billet (1er, 2eme ou 3eme class) __(int)__
# __Name__ : Nom de la personne __(string)__
# __Sex__ : Homme ou Femme __(string)__
# __SibSp__ : Si il y a des frère, soeur, demi-frère, demi-soeur, époux, épouse. (les maîtresses et les fiancées ont été ignorées) __(int)__
# __Parch__ : Parent = mère, père. Enfant = fille, fils, belle-fille, beau-fils. Certains enfants voyageaient uniquement avec une nourrice, donc parch = 0 pour eux.  __(int)__
# __Ticket__ : Numéro du ticket __(string)__
# __Fare__ : Prix du billet  __(int)__
# __Cabin__ : Numéro de cabine  __(string)__
# __Embarked__ : Point d'entrée lors de l'embarquement  __(string)__

# %% [markdown]
# Dans le dataframe, il y a 890 lignes pour 12 collonnes.

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Nous pouvons voir que dans la colonne "age" il y a des valeurs nulle

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ### 2-2 Normalisation de la colone Name
# Nous allons normaliser tout d'abord la colonne des noms pour harmoniser les titres mr, mrs etc etc ..

# %%
train = copy_train
train["Title"] = ""
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked Title
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %%
s = []
for dataset in train["Name"]:
    s.append(pd.Series(dataset).str.extract(r' ([A-Za-z]+)\.', expand=False))
train["Title"] = s
train["Title"] = train["Title"].map(lambda name:name.to_string().replace("0   ", "").split(' ', 2)[1])

# %%
train["Title"].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Major         2
# Mlle          2
# Ms            1
# Countess      1
# Sir           1
# Mme           1
# Jonkheer      1
# Capt          1
# Lady          1
# Don           1
# Name: Title, dtype: int64

# %%
Title_Dict = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir" : "Royalty",
    "Dr": "Officer",
    "Rev": "Officer",
    "Countess":"Royalty",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr" : "Mr",
    "Mrs" : "Mrs",
    "Miss" : "Miss",
    "Master" : "Master",
    "Lady" : "Royalty"
}

# %%
train['Title'] = train.Title.map(Title_Dict)
train["Title"].value_counts()
# Out:
# Mr         517
# Miss       184
# Mrs        127
# Master      40
# Officer     18
# Royalty      5
# Name: Title, dtype: int64

# %% [markdown]
# D'autres test auraient pu etre faits pour trouver les incoherence plus subtils. Par exemple regarder qu'il y a bien des ecarts d'age pour des meme nom de familles (). Ou des erreurs d'orthographes (Utiliser pour cela l'algo de leventsein pour calculer les distances). Regarder les liens de familles et verifier que les personnes etaient bien presentes (faire une fonction de trie par famille puis par no; avec un str compare, ou isoler les nom de famille)
# j'ai la flemme de le faire la :)

# %% [markdown]
# ### 2-2-0 Remplacement des valeurs manquantes d'embarkements

# %%
train[train["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Title
# 61   female  38.0      0      0  113572  80.0   B28      NaN  Miss
# 829  female  62.0      0      0  113572  80.0   B28      NaN   Mrs

# %%
class_one = len(train[train["Embarked"] == "Q"])
class_two = len(train[train["Embarked"] == "S"])
class_three = len(train[train["Embarked"] == "E"])

name = ['Q', 'S', "E"]
data = [class_one, class_two, class_three]
explode=(0.2, 0.20, 0.20)
plt.pie(data, explode=explode, labels=name, autopct='%1.1f%%', startangle=90, shadow=True)
plt.axis('equal')
plt.show()

# %% [markdown]
# je decide donc de dire que les 2 embarkement appartiennent a l'embarkement S

# %%
train["Embarked"].fillna('S',inplace=True)

# %% [markdown]
# ### 2-2 Etude des Ages

# %% [markdown]
# Le but étant de savoir si on :
# - efface les donées manquante (si > 20% des données)
# - remplace les données manquante (moyenne, médiane, etc etc)
# - Création d'un algo qui va segmenter les parties atribuer les valeurs (attention à na pas induire le dataset en erreur)

# %%
Image(url= "https://cdn-images-1.medium.com/max/1600/1*_RA3mCS30Pr0vUxbp25Yxw.png")
# Out:
# <img src="https://cdn-images-1.medium.com/max/1600/1*_RA3mCS30Pr0vUxbp25Yxw.png"/>

# %% [markdown]
# Ce shemas indique la maiere dont nous pouvons essayer de traiter les donnes a analyser.
# dans notre cas nous pouvons essayer les multiples imputations en essaayant de segmenter au mieux la donne pour la remplacer par des medianne de sous groupe. Nous avons aussi la regression logistic (par exemple la methode KNN pour affiner au mieux les resultats).

# %% [markdown]
# Nous allons voir la repartition entre les femmes et hommes pour remplacer potentiellement les valeurs nulles
# d'Age des femmes par la médianne des femme et pareil pour les hommes

# %%
empty_age = train[train["Age"].isnull()]
empty_age.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 5             6         0       3
# 17           18         1       2
# 19           20         1       3
# 26           27         0       3
# 28           29         1       3
# 29           30         0       3
# 31           32         1       1
# 32           33         1       3
# 36           37         1       3
# 42           43         0       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 55           56         1       1
# 64           65         0       1
# 65           66         1       3
# 76           77         0       3
# 77           78         0       3
# 82           83         1       3
#
#                                               Name     Sex  Age  SibSp  Parch  \
# 5                                 Moran, Mr. James    male  NaN      0      0
# 17                    Williams, Mr. Charles Eugene    male  NaN      0      0
# 19                         Masselmani, Mrs. Fatima  female  NaN      0      0
# 26                         Emir, Mr. Farred Chehab    male  NaN      0      0
# 28                   O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0      0
# 29                             Todoroff, Mr. Lalio    male  NaN      0      0
# 31  Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1      0
# 32                        Glynn, Miss. Mary Agatha  female  NaN      0      0
# 36                                Mamee, Mr. Hanna    male  NaN      0      0
# 42                             Kraeff, Mr. Theodor    male  NaN      0      0
# 45                        Rogers, Mr. William John    male  NaN      0      0
# 46                               Lennon, Mr. Denis    male  NaN      1      0
# 47                       O'Driscoll, Miss. Bridget  female  NaN      0      0
# 48                             Samaan, Mr. Youssef    male  NaN      2      0
# 55                               Woolner, Mr. Hugh    male  NaN      0      0
# 64                           Stewart, Mr. Albert A    male  NaN      0      0
# 65                        Moubarek, Master. Gerios    male  NaN      1      1
# 76                               Staneff, Mr. Ivan    male  NaN      0      0
# 77                        Moutal, Mr. Rahamin Haim    male  NaN      0      0
# 82                  McDermott, Miss. Brigdet Delia  female  NaN      0      0
#
#              Ticket      Fare Cabin Embarked   Title
# 5            330877    8.4583   NaN        Q      Mr
# 17           244373   13.0000   NaN        S      Mr
# 19             2649    7.2250   NaN        C     Mrs
# 26             2631    7.2250   NaN        C      Mr
# 28           330959    7.8792   NaN        Q    Miss
# 29           349216    7.8958   NaN        S      Mr
# 31         PC 17569  146.5208   B78        C     Mrs
# 32           335677    7.7500   NaN        Q    Miss
# 36             2677    7.2292   NaN        C      Mr
# 42           349253    7.8958   NaN        C      Mr
# 45  S.C./A.4. 23567    8.0500   NaN        S      Mr
# 46           370371   15.5000   NaN        Q      Mr
# 47            14311    7.7500   NaN        Q    Miss
# 48             2662   21.6792   NaN        C      Mr
# 55            19947   35.5000   C52        S      Mr
# 64         PC 17605   27.7208   NaN        C      Mr
# 65             2661   15.2458   NaN        C  Master
# 76           349208    7.8958   NaN        S      Mr
# 77           374746    8.0500   NaN        S      Mr
# 82           330932    7.7875   NaN        Q    Miss

# %% [markdown]
# #### Répartition du nombre de femmes et hommes dans les données manquantes

# %%
len_femme = len(empty_age[empty_age["Sex"] == "female"])
len_homme = len(empty_age[empty_age["Sex"] == "male"])
name = ['female', 'Male']
data = [len_femme, len_homme]
explode=(0, 0.10)
plt.pie(data, explode=explode, labels=name, autopct='%1.1f%%', startangle=90, shadow=True)
plt.axis('equal')
plt.show()

Q_embarked = len(empty_age[empty_age["Embarked"] == "Q"])
s_embarked = len(empty_age[empty_age["Embarked"] == "S"])
C_embarked = len(empty_age[empty_age["Embarked"] == "C"])

name = ['Q', 'S', 'C']
data = [Q_embarked, s_embarked, C_embarked]
explode=(0, 0.10, 0.10)
plt.pie(data, explode=explode, labels=name, autopct='%1.1f%%', startangle=90, shadow=True)
plt.axis('equal')
plt.show()

class_one = len(empty_age[empty_age["Pclass"] == 1])
class_two = len(empty_age[empty_age["Pclass"] == 2])
class_three = len(empty_age[empty_age["Pclass"] == 3])

name = ['1er class', '2 eme class', "3 eme class"]
data = [class_one, class_two, class_three]
explode=(0, 0.10, 0.10)
plt.pie(data, explode=explode, labels=name, autopct='%1.1f%%', startangle=90, shadow=True)
plt.axis('equal')
plt.show()

# %% [markdown]
# 70% Des données manquantes proviennent majoritairement d'hommmes. Nous allons étudier la distribution des données des hommes et femmes.

# %% [markdown]
# les camember en cercle n'étant pas égale en valeurs. Nous allons utiliser la médiane pour "Pclass", "Sex", "Embarked" mais aussi "Title", cela, Afin d'affiner les résulat de manire plus precise.
# Nous allons calculer la medianne en prennant ses 4 colonnes pour ensuite les attribuer aux valeurs manquantes.

# %%
copy = train
cop = copy.iloc[0:len(copy)].groupby(["Sex","Pclass","Embarked", "Title"]).median()
cop = cop.reset_index()[['Sex', 'Pclass', 'Title', 'Embarked','Age']]
print(cop)
# Out:
#        Sex  Pclass    Title Embarked    Age
# 0   female       1     Miss        C  30.50
# 1   female       1      Mrs        C  44.00
# 2   female       1  Royalty        C  48.00
# 3   female       1     Miss        Q  33.00
# 4   female       1     Miss        S  23.50
# 5   female       1      Mrs        S  39.00
# 6   female       1  Officer        S  49.00
# 7   female       1  Royalty        S  33.00
# 8   female       2     Miss        C  17.00
# 9   female       2      Mrs        C  22.50
# 10  female       2     Miss        Q  30.00
# 11  female       2     Miss        S  24.00
# 12  female       2      Mrs        S  33.00
# 13  female       3     Miss        C  11.00
# 14  female       3      Mrs        C  26.50
# 15  female       3     Miss        Q  18.50
# 16  female       3      Mrs        Q  35.50
# 17  female       3     Miss        S  19.00
# 18  female       3      Mrs        S  31.00
# 19    male       1       Mr        C  36.00
# 20    male       1  Officer        C  44.00
# 21    male       1  Royalty        C  44.50
# 22    male       1  Officer        Q  44.00
# 23    male       1   Master        S   4.00
# 24    male       1       Mr        S  42.00
# 25    male       1  Officer        S  52.00
# 26    male       1  Royalty        S  38.00
# 27    male       2   Master        C   1.00
# 28    male       2       Mr        C  30.00
# 29    male       2  Officer        Q  57.00
# 30    male       2   Master        S   1.50
# 31    male       2       Mr        S  31.00
# 32    male       2  Officer        S  42.00
# 33    male       3   Master        C   6.21
# 34    male       3       Mr        C  26.00
# 35    male       3   Master        Q   5.50
# 36    male       3       Mr        Q  31.50
# 37    male       3   Master        S   4.00
# 38    male       3       Mr        S  26.00

# %%
def get_info(col):
    cond = (
            (cop["Sex"] == col["Sex"]) & 
            (cop["Pclass"] == col["Pclass"]) & 
            (cop["Embarked"] == col["Embarked"]) & 
            (cop["Title"] == col["Title"])
           )
    return cop[cond]["Age"].values[0]


def transform(col):
    stock = get_info(col) 
    if np.isnan(col["Age"]):
        print("Age", col["Age"], "stock", stock, "name",col["Name"])
        return stock
    else:
        return col["Age"]

train["Age"] = train.apply(lambda col: transform(col), axis=1)
# Out:
# Age nan stock 31.5 name Moran, Mr. James
# Age nan stock 31.0 name Williams, Mr. Charles Eugene
# Age nan stock 26.5 name Masselmani, Mrs. Fatima
# Age nan stock 26.0 name Emir, Mr. Farred Chehab
# Age nan stock 18.5 name O'Dwyer, Miss. Ellen "Nellie"
# Age nan stock 26.0 name Todoroff, Mr. Lalio
# Age nan stock 44.0 name Spencer, Mrs. William Augustus (Marie Eugenie)
# Age nan stock 18.5 name Glynn, Miss. Mary Agatha
# Age nan stock 26.0 name Mamee, Mr. Hanna
# Age nan stock 26.0 name Kraeff, Mr. Theodor
# Age nan stock 26.0 name Rogers, Mr. William John
# Age nan stock 31.5 name Lennon, Mr. Denis
# Age nan stock 18.5 name O'Driscoll, Miss. Bridget
# Age nan stock 26.0 name Samaan, Mr. Youssef
# Age nan stock 42.0 name Woolner, Mr. Hugh
# Age nan stock 36.0 name Stewart, Mr. Albert A
# Age nan stock 6.21 name Moubarek, Master. Gerios
# Age nan stock 26.0 name Staneff, Mr. Ivan
# Age nan stock 26.0 name Moutal, Mr. Rahamin Haim
# Age nan stock 18.5 name McDermott, Miss. Brigdet Delia
# Age nan stock 26.0 name Slocovski, Mr. Selman Francis
# Age nan stock 26.0 name Shorney, Mr. Charles Joseph
# Age nan stock 26.0 name Petroff, Mr. Pastcho ("Pentcho")
# Age nan stock 26.0 name Moss, Mr. Albert Johan
# Age nan stock 18.5 name Moran, Miss. Bertha
# Age nan stock 26.0 name Moore, Mr. Leonard Charles
# Age nan stock 31.5 name McMahon, Mr. Martin
# Age nan stock 11.0 name Peter, Miss. Anna
# Age nan stock 26.5 name Boulos, Mrs. Joseph (Sultana)
# Age nan stock 26.0 name Olsen, Mr. Ole Martin
# Age nan stock 26.0 name Smiljanic, Mr. Mile
# Age nan stock 4.0 name Sage, Master. Thomas Henry
# Age nan stock 39.0 name Chibnall, Mrs. (Edith Martha Bowerman)
# Age nan stock 42.0 name Baumann, Mr. John D
# Age nan stock 4.0 name Lefebre, Master. Henry Forbes
# Age nan stock 19.0 name Sage, Miss. Constance Gladys
# Age nan stock 30.0 name Pernot, Mr. Rene
# Age nan stock 42.0 name Rood, Mr. Hugh Roscoe
# Age nan stock 35.5 name O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)
# Age nan stock 31.5 name Mernagh, Mr. Robert
# Age nan stock 18.5 name Madigan, Miss. Margaret "Maggie"
# Age nan stock 26.0 name Sage, Mr. Frederick
# Age nan stock 31.5 name Kiernan, Mr. Philip
# Age nan stock 26.0 name Nenkoff, Mr. Christo
# Age nan stock 19.0 name Lefebre, Miss. Mathilde
# Age nan stock 19.0 name Harknett, Miss. Alice Phoebe
# Age nan stock 11.0 name Zabour, Miss. Thamine
# Age nan stock 18.5 name Murphy, Miss. Katherine "Kate"
# Age nan stock 26.0 name Reed, Mr. James George
# Age nan stock 44.0 name Thorne, Mrs. Gertrude Maybelle
# Age nan stock 31.5 name Smith, Mr. Thomas
# Age nan stock 18.5 name Henry, Miss. Delia
# Age nan stock 42.0 name Cairns, Mr. Alexander
# Age nan stock 18.5 name Healy, Miss. Hanora "Nora"
# Age nan stock 31.0 name Parkes, Mr. Francis "Frank"
# Age nan stock 42.0 name Smith, Mr. Richard William
# Age nan stock 36.0 name Lewy, Mr. Ervin G
# Age nan stock 42.0 name Saalfeld, Mr. Adolphe
# Age nan stock 18.5 name Kelly, Miss. Anna Katherine "Annie Kate"
# Age nan stock 31.5 name McCoy, Mr. Bernard
# Age nan stock 30.0 name Keane, Miss. Nora A
# Age nan stock 26.0 name Williams, Mr. Howard Hugh "Harry"
# Age nan stock 30.5 name Fleming, Miss. Margaret
# Age nan stock 26.0 name Sage, Mr. George John Jr
# Age nan stock 18.5 name McCoy, Miss. Agnes
# Age nan stock 39.0 name Frauenthal, Mrs. Henry William (Clara Heinsheimer)
# Age nan stock 26.0 name Denkoff, Mr. Mitto
# Age nan stock 31.0 name Davison, Mrs. Thomas Henry (Mary E Finck)
# Age nan stock 42.0 name Williams-Lambert, Mr. Fletcher Fellows
# Age nan stock 26.0 name Yousif, Mr. Wazli
# Age nan stock 18.5 name McGovern, Miss. Mary
# Age nan stock 18.5 name Mockler, Miss. Helen Mary "Ellie"
# Age nan stock 31.5 name O'Brien, Mr. Thomas
# Age nan stock 26.5 name Moussa, Mrs. (Mantoura Boulos)
# Age nan stock 18.5 name Jermyn, Miss. Annie
# Age nan stock 44.0 name Meyer, Mrs. Edgar Joseph (Leila Saks)
# Age nan stock 26.0 name Plotcharsky, Mr. Vasil
# Age nan stock 31.5 name Sadlier, Mr. Matthew
# Age nan stock 19.0 name Lefebre, Miss. Ida
# Age nan stock 26.0 name Sdycoff, Mr. Todor
# Age nan stock 31.5 name Hart, Mr. Henry
# Age nan stock 31.0 name Cunningham, Mr. Alfred Fleming
# Age nan stock 31.0 name Meek, Mrs. Thomas (Annie Louise Rowley)
# Age nan stock 26.0 name Gheorgheff, Mr. Stanio
# Age nan stock 26.0 name Wiseman, Mr. Phillippe
# Age nan stock 31.5 name Flynn, Mr. James
# Age nan stock 31.0 name Thorneycroft, Mrs. Percival (Florence Kate White)
# Age nan stock 26.0 name Johannesen-Bratthammer, Mr. Bernt
# Age nan stock 26.0 name Hagland, Mr. Ingvald Olai Olsen
# Age nan stock 26.0 name Peduzzi, Mr. Joseph
# Age nan stock 39.0 name Kenyon, Mrs. Frederick R (Marion)
# Age nan stock 31.5 name O'Connor, Mr. Maurice
# Age nan stock 26.0 name Maisner, Mr. Simon
# Age nan stock 31.0 name Campbell, Mr. William
# Age nan stock 31.5 name Scanlan, Mr. James
# Age nan stock 26.0 name Keefe, Mr. Arthur
# Age nan stock 42.0 name Clifford, Mr. George Quincy
# Age nan stock 31.0 name Frost, Mr. Anthony Wood "Archie"
# Age nan stock 19.0 name Lefebre, Miss. Jeannie
# Age nan stock 26.0 name Hagland, Mr. Konrad Mathias Reiersen
# Age nan stock 26.0 name Yousseff, Mr. Gerious
# Age nan stock 26.0 name Shellard, Mr. Frederick William
# Age nan stock 18.5 name O'Sullivan, Miss. Bridget Mary
# Age nan stock 42.0 name Bradley, Mr. George ("George Arthur Brayton")
# Age nan stock 26.0 name Webber, Mr. James
# Age nan stock 31.5 name Ryan, Mr. Patrick
# Age nan stock 26.0 name Lahoud, Mr. Sarkis
# Age nan stock 26.0 name Kassem, Mr. Fared
# Age nan stock 42.0 name Farthing, Mr. John
# Age nan stock 26.0 name Toufik, Mr. Nakli
# Age nan stock 26.5 name Peter, Mrs. Catherine (Catherine Rizk)
# Age nan stock 26.0 name Risien, Mr. Samuel Beard
# Age nan stock 30.0 name Padro y Manent, Mr. Julian
# Age nan stock 31.5 name O'Brien, Mr. Timothy
# Age nan stock 36.0 name Robbins, Mr. Victor
# Age nan stock 31.5 name Morrow, Mr. Thomas Rowan
# Age nan stock 26.0 name Simmons, Mr. John
# Age nan stock 19.0 name Meanwell, Miss. (Marion Ogden)
# Age nan stock 26.0 name Doharr, Mr. Tannous
# Age nan stock 18.5 name Kelly, Miss. Mary
# Age nan stock 26.5 name Caram, Mrs. Joseph (Maria Elias)
# Age nan stock 26.0 name Paulner, Mr. Uscher
# Age nan stock 26.0 name Murdlin, Mr. Joseph
# Age nan stock 18.5 name Bourke, Miss. Mary
# Age nan stock 24.0 name Leitch, Miss. Jessie Wills
# Age nan stock 26.0 name Boulos, Mr. Hanna
# Age nan stock 26.0 name Slabenoff, Mr. Petco
# Age nan stock 42.0 name Harrington, Mr. Charles H
# Age nan stock 26.0 name Jardin, Mr. Jose Neto
# Age nan stock 18.5 name Murphy, Miss. Margaret Jane
# Age nan stock 31.5 name Horgan, Mr. John
# Age nan stock 31.5 name O'Connell, Mr. Patrick D
# Age nan stock 42.0 name Parr, Mr. William Henry Marsh
# Age nan stock 26.0 name Thorneycroft, Mr. Percival
# Age nan stock 26.0 name Foo, Mr. Choong
# Age nan stock 26.0 name Willey, Mr. Edward
# Age nan stock 26.0 name Mitkoff, Mr. Mito
# Age nan stock 18.5 name O'Leary, Miss. Hanora "Norah"
# Age nan stock 26.0 name Radeff, Mr. Alexander
# Age nan stock 26.0 name Rommetvedt, Mr. Knud Paust
# Age nan stock 39.0 name Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)
# Age nan stock 31.0 name Watson, Mr. Ennis Hastings
# Age nan stock 18.5 name Peters, Miss. Katie
# Age nan stock 26.0 name Lam, Mr. Ali
# Age nan stock 18.5 name Mullens, Miss. Katherine "Katie"
# Age nan stock 6.21 name Moubarek, Master. Halim Gonios ("William George")
# Age nan stock 42.0 name Klaber, Mr. Herman
# Age nan stock 31.5 name McEvoy, Mr. Michael
# Age nan stock 18.5 name Mannion, Miss. Margareth
# Age nan stock 31.0 name Knight, Mr. Robert J
# Age nan stock 26.0 name Ivanoff, Mr. Kanio
# Age nan stock 26.0 name Nankoff, Mr. Minko
# Age nan stock 42.0 name Hawksford, Mr. Walter James
# Age nan stock 26.0 name Garfirth, Mr. John
# Age nan stock 44.0 name Brewe, Dr. Arthur Jackson
# Age nan stock 31.5 name Moran, Mr. Daniel J
# Age nan stock 26.0 name Elias, Mr. Dibo
# Age nan stock 31.5 name Tobin, Mr. Roger
# Age nan stock 31.5 name Kilgannon, Mr. Thomas J
# Age nan stock 26.0 name Johnston, Mr. Andrew G
# Age nan stock 31.5 name Keane, Mr. Andrew "Andy"
# Age nan stock 19.0 name Sage, Miss. Stella Anna
# Age nan stock 36.0 name Hoyt, Mr. William Fisher
# Age nan stock 42.0 name Fry, Mr. Richard
# Age nan stock 31.5 name Flynn, Mr. John
# Age nan stock 26.0 name Lam, Mr. Len
# Age nan stock 31.5 name McCormack, Mr. Thomas Joseph
# Age nan stock 26.0 name Saad, Mr. Amin
# Age nan stock 26.0 name Sirota, Mr. Maurice
# Age nan stock 36.0 name Marechal, Mr. Pierre
# Age nan stock 26.0 name Sage, Mr. Douglas Bullen
# Age nan stock 44.0 name Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# Age nan stock 26.0 name Razi, Mr. Raihed
# Age nan stock 19.0 name Sage, Miss. Dorothy Edith "Dolly"
# Age nan stock 26.0 name van Melkebeke, Mr. Philemon
# Age nan stock 26.0 name Laleff, Mr. Kristo
# Age nan stock 19.0 name Johnston, Miss. Catherine Helen "Carrie"

# %% [markdown]
# ### 2-2-3 Cabin

# %%
empty_cabin = train[train["Cabin"].isnull()]

# %%
len_femme = len(empty_cabin[empty_cabin["Sex"] == "female"])
len_homme = len(empty_cabin[empty_cabin["Sex"] == "male"])
name = ['female', 'Male']
data = [len_femme, len_homme]
explode=(0, 0.10)
plt.pie(data, explode=explode, labels=name, autopct='%1.1f%%', startangle=90, shadow=True)
plt.axis('equal')
plt.show()

class_one = len(empty_cabin[empty_cabin["Pclass"] == 1])
class_two = len(empty_cabin[empty_cabin["Pclass"] == 2])
class_three = len(empty_cabin[empty_cabin["Pclass"] == 3])

name = ['1er class', '2 eme class', "3 eme class"]
data = [class_one, class_two, class_three]
explode=(0, 0.10, 0.10)
plt.pie(data, explode=explode, labels=name, autopct='%1.1f%%', startangle=90, shadow=True)
plt.axis('equal')
plt.show()

Q_embarked = len(empty_cabin[empty_cabin["Embarked"] == "Q"])
s_embarked = len(empty_cabin[empty_cabin["Embarked"] == "S"])
C_embarked = len(empty_cabin[empty_cabin["Embarked"] == "C"])

name = ['Q', 'S', 'C']
data = [Q_embarked, s_embarked, C_embarked]
explode=(0, 0.10, 0.10)
plt.pie(data, explode=explode, labels=name, autopct='%1.1f%%', startangle=90, shadow=True)
plt.axis('equal')
plt.show()

# %%
value_Pclass = 3
value_sex = "male"
value_embarked = "S"

cond = ((train["Sex"] == value_sex) & (train["Pclass"] == value_Pclass) & (train["Embarked"] == value_embarked))

train[cond]["Cabin"].value_counts()
# Out:
# F G73    2
# E121     1
# F G63    1
# E10      1
# Name: Cabin, dtype: int64

# %% [markdown]
# Il est assez complique d'essayer de completer ses donnes au vu du peu de donne present. je vais donc remplacer les donnes manquantes par des "U" = unknow.

# %%
train["Cabin"].fillna('U',inplace=True)

# %%
train["Cabin"].value_counts()
# Out:
# U                  687
# C23 C25 C27          4
# G6                   4
# B96 B98              4
# D                    3
# F33                  3
# C22 C26              3
# F2                   3
# E101                 3
# C92                  2
# C78                  2
# B28                  2
# D26                  2
# E67                  2
# D36                  2
# D33                  2
# D20                  2
# D17                  2
# B49                  2
# E33                  2
# D35                  2
# B51 B53 B55          2
# B18                  2
# E8                   2
# C124                 2
# C52                  2
# C65                  2
# C126                 2
# E25                  2
# C125                 2
# B57 B59 B63 B66      2
# C123                 2
# C83                  2
# B58 B60              2
# E121                 2
# B77                  2
# C93                  2
# B20                  2
# C68                  2
# C2                   2
# E24                  2
# F G73                2
# B35                  2
# F4                   2
# E44                  2
# B22                  2
# B5                   2
# D45                  1
# C32                  1
# C49                  1
#                   ...
# C82                  1
# C30                  1
# C103                 1
# D7                   1
# B3                   1
# D49                  1
# D50                  1
# D15                  1
# A34                  1
# D47                  1
# A16                  1
# C95                  1
# D48                  1
# B79                  1
# D46                  1
# A7                   1
# A36                  1
# B37                  1
# B86                  1
# C128                 1
# D11                  1
# B19                  1
# E10                  1
# A6                   1
# C85                  1
# B73                  1
# C45                  1
# C86                  1
# C104                 1
# B30                  1
# E50                  1
# D10 D12              1
# D37                  1
# E46                  1
# B80                  1
# E38                  1
# F G63                1
# C54                  1
# C70                  1
# C7                   1
# D6                   1
# A10                  1
# A26                  1
# C87                  1
# E77                  1
# A19                  1
# A20                  1
# D21                  1
# D56                  1
# A5                   1
# Name: Cabin, Length: 148, dtype: int64

# %%
# verification
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Title          0
# dtype: int64

# %%
ld = []

def get_error(string):
    if '(' in string:
        return 1
    else:
        return 0

for data in train["Name"]:
    mrs = ""
    mrs_1 = ""
    mrs_2 = ""
    name, rest = data.split(",", 1)
    title, mrs = rest.split(".", 1)
    if get_error(mrs):
        mrs_1, mrs_2 = mrs.strip().split("(", 1)
        mrs_1 = mrs_1.strip(" ")
        mrs_2 = mrs_2.replace(")", "")
        ld.append([name, title, mrs_1, mrs_2])
    else:
        ld.append([name, title, mrs.strip(" ")])

ld[0:3]
# Out:
# [['Braund', ' Mr', 'Owen Harris'],
#  ['Cumings', ' Mrs', 'John Bradley', 'Florence Briggs Thayer'],
#  ['Heikkinen', ' Miss', 'Laina']]

# %% [markdown]
# Nous pouvons voir qu'il n'y a pas d'erreur et que les nom entre parentheses ont ete donne qu'au femme marie

# %%
for data in ld:
    if (data[1] == "Miss" and len(data > 1)):
        print(data)
    if (data[1] == "Mr" and len(data > 1)):
        print(data)
    if (data[1] == "Officer" and len(data > 1)):
        print(data)

# %% [markdown]
# ### 3 - 1 Transformation du dataset pour les algos

# %%
train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500     U        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250     U        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# 4      0            373450   8.0500     U        S    Mr

# %% [markdown]
# les col PassengerId, Name, Ticket, Cabin

# %% [markdown]
# ### En fonction de l'age

# %%
train['Child'] = 0
train.loc[train['Age'] < 15, 'Child'] = 1

# %%
train['Elderly'] = 0
train.loc[train['Age'] > 62, 'Elderly'] = 1

# %%
train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Child  Elderly
# 0      0         A/5 21171   7.2500     U        S    Mr      0        0
# 1      0          PC 17599  71.2833   C85        C   Mrs      0        0
# 2      0  STON/O2. 3101282   7.9250     U        S  Miss      0        0
# 3      0            113803  53.1000  C123        S   Mrs      0        0
# 4      0            373450   8.0500     U        S    Mr      0        0

# %%
sns.barplot(x="Child", y="Survived", data=train)

# %%
sns.barplot(x="Elderly", y="Survived", data=train)

# %% [markdown]
# Nous pouvons voir que les personnes ages avaient moin de chances de survivre. les Enfants eux oui.

# %% [markdown]
# ### Transformation du dataset pour la preparations aux algo

# %%
# Dico embarked
dico_e = {"S":1, "C":2, "Q": 3}
dico_sex = {"female":1, "male": 2}
dico_title = {
    "Officer": 1,
    "Royalty": 2,
    "Mrs": 3,
    "Miss": 4,
    "Mr": 5,
    "Master": 6,
}

# Appliquer les transformations
train['Embarked'] = train.Embarked.map(dico_e)
train['Sex'] = train.Sex.map(dico_sex)
train['Title'] = train.Title.map(dico_title)

# %%
train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    2  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    2  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  Title  Child  Elderly
# 0         A/5 21171   7.2500     U         1      5      0        0
# 1          PC 17599  71.2833   C85         2      3      0        0
# 2  STON/O2. 3101282   7.9250     U         1      4      0        0
# 3            113803  53.1000  C123         1      3      0        0
# 4            373450   8.0500     U         1      5      0        0

# %%
#train["Age"].fillna(train.groupby(["Pclass", "Sex", "Embarked"])["Age"].transform("median"), inplace=True)

# %%
#train.groupby(["Pclass", "Sex", "Embarked"])["Age"].transform("median")
#verif = data_cpy[(data_cpy["Pclass"] == 3) & (data_cpy["Sex"] == "male" ) & (data_cpy["Embarked"] == "Q")]
#verif.head(5)

# %%
#verif = data_cpy[(data_cpy["Pclass"] == 3) & (data_cpy["Embarked"] == "Q")]
#verif.head(5)

# %%
### image = wget "https://cdn-images-1.medium.com/max/1400/1*_RA3mCS30Pr0vUxbp25Yxw.png"
### copier cela a 1-1-1 pour reprensenter les choix que nous avons pour selectionner les valeurs manquqntes

# %%
#########################################################################################
#########################################################################################
#########################################################################################
### AIDES

# %%
#male = empty_age[empty_age["Sex"] == "male"]
#femm = empty_age[empty_age["Sex"] == "femelle"]

#ax = male.plot(kind="bar", y="Age", x="Fare", figsize=(16,10), color="red")
#ax.set_title("Distribution des écarts d'âge entre mari et femme");

# %%
#ax = male[male["Age"]].hist(figsize=(16,6), bins=50)
#ax.set_title("Distribution des écarts d'âge entre mari et femme");

# %%
#Nuage de points a faire .. 
#empty_age.plot(kind='hexbin', x="age", y="age", gridsize=25, figsize=(7,6))
#ax.set_title("Heatmap - âge entre mari et femmes")

# %%
#def bar_chart(feature):
##    survived = train[train['Survived']==1][feature].value_counts()
#    dead = train[train['Survived']==0][feature].value_counts()
#    df = pd.DataFrame([survived,dead])
#    df.index = ['Survived','Dead']
#    df.plot(kind='bar',stacked=True, figsize=(10,5))
